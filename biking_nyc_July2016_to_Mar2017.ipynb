# %%
# dependencies

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import scipy.stats as stats

# %% [markdown]
# ### Bring in the CSVs going back 3 years

# %%
# load the files

folder = "extracted_csvs/"
rest_of_file = "-citibike-tripdata.csv"

bike_2016_07 = folder + "201607" + rest_of_file
bike_2016_08 = folder + "201608" + rest_of_file
bike_2016_09 = folder + "201609" + rest_of_file
bike_2016_10 = folder + "201610" + rest_of_file
bike_2016_11 = folder + "201611" + rest_of_file
bike_2016_12 = folder + "201612" + rest_of_file
bike_2017_01 = folder + "201701" + rest_of_file
bike_2017_02 = folder + "201702" + rest_of_file
bike_2017_03 = folder + "201703" + rest_of_file
# bike_2017_04 = folder + "201704" + rest_of_file
# bike_2017_05 = folder + "201705" + rest_of_file
# bike_2017_06 = folder + "201706" + rest_of_file
# bike_2017_07 = folder + "201707" + rest_of_file
# bike_2017_08 = folder + "201708" + rest_of_file
# bike_2017_09 = folder + "201709" + rest_of_file
# bike_2017_10 = folder + "201710" + rest_of_file
# bike_2017_11 = folder + "201711" + rest_of_file
# bike_2017_12 = folder + "201712" + rest_of_file
# bike_2018_01 = folder + "201801" + rest_of_file
# bike_2018_02 = folder + "201802" + rest_of_file
# bike_2018_03 = folder + "201803" + rest_of_file
# bike_2018_04 = folder + "201804" + rest_of_file
# bike_2018_05 = folder + "201805" + rest_of_file
# bike_2018_06 = folder + "201806" + rest_of_file
# bike_2018_07 = folder + "201807" + rest_of_file
# bike_2018_08 = folder + "201808" + rest_of_file
# bike_2018_09 = folder + "201809" + rest_of_file
# bike_2018_10 = folder + "201810" + rest_of_file
# bike_2018_11 = folder + "201811" + rest_of_file
# bike_2018_12 = folder + "201812" + rest_of_file
# bike_2019_01 = folder + "201901" + rest_of_file
# bike_2019_02 = folder + "201902" + rest_of_file
# bike_2019_03 = folder + "201903" + rest_of_file
# bike_2019_04 = folder + "201904" + rest_of_file
# bike_2019_05 = folder + "201905" + rest_of_file
# bike_2019_06 = folder + "201906" + rest_of_file
# bike_2019_07 = folder + "201907" + rest_of_file

# %% [markdown]
# ## July 2016

# %%
# read files into dataframe
df_2016_07 = pd.read_csv(bike_2016_07)
# show DF1
df_2016_07.head()
# Out:
#    tripduration          starttime           stoptime  start station id  \
# 0           704  7/1/2016 00:00:02  7/1/2016 00:11:47               459
# 1           492  7/1/2016 00:00:18  7/1/2016 00:08:31               293
# 2           191  7/1/2016 00:00:19  7/1/2016 00:03:31              3090
# 3           687  7/1/2016 00:00:24  7/1/2016 00:11:52               459
# 4           609  7/1/2016 00:00:31  7/1/2016 00:10:40               284
#
#       start station name  start station latitude  start station longitude  \
# 0       W 20 St & 11 Ave               40.746745               -74.007756
# 1  Lafayette St & E 8 St               40.730287               -73.990765
# 2    N 8 St & Driggs Ave               40.717746               -73.956001
# 3       W 20 St & 11 Ave               40.746745               -74.007756
# 4  Greenwich Ave & 8 Ave               40.739017               -74.002638
#
#    end station id             end station name  end station latitude  \
# ...

# %%
# get # of rows for DF1
df_1607_rows = df_2016_07.count()
print(df_1607_rows)
# Out:
# tripduration               1380110
# starttime                  1380110
# stoptime                   1380110
# start station id           1380110
# start station name         1380110
# start station latitude     1380110
# start station longitude    1380110
# end station id             1380110
# end station name           1380110
# end station latitude       1380110
# end station longitude      1380110
# bikeid                     1380110
# usertype                   1380110
# birth year                 1176515
# gender                     1380110
# dtype: int64

# %% [markdown]
# ## Aug 2016

# %%
# read files into dataframe for DF2
df_2016_08 = pd.read_csv(bike_2016_08)
# show dataframe DF2
df_2016_08.head()
# Out:
#    tripduration          starttime           stoptime  start station id  \
# 0           288  8/1/2016 00:01:22  8/1/2016 00:06:11               302
# 1           457  8/1/2016 00:01:43  8/1/2016 00:09:21               285
# 2           278  8/1/2016 00:02:10  8/1/2016 00:06:49               539
# 3           862  8/1/2016 00:02:13  8/1/2016 00:16:36               280
# 4           407  8/1/2016 00:02:21  8/1/2016 00:09:09               161
#
#                start station name  start station latitude  \
# 0               Avenue D & E 3 St               40.720828
# 1              Broadway & E 14 St               40.734546
# 2  Metropolitan Ave & Bedford Ave               40.715348
# 3                 E 10 St & 5 Ave               40.733320
# 4           LaGuardia Pl & W 3 St               40.729170
#
#    start station longitude  end station id     end station name  \
# 0               -73.977932             428       E 3 St & 1 Ave
# ...

# %%
# get # of rows for DF2
df_1608_rows = df_2016_08.count()
print(df_1608_rows)
# Out:
# tripduration               1557663
# starttime                  1557663
# stoptime                   1557663
# start station id           1557663
# start station name         1557663
# start station latitude     1557663
# start station longitude    1557663
# end station id             1557663
# end station name           1557663
# end station latitude       1557663
# end station longitude      1557663
# bikeid                     1557663
# usertype                   1557663
# birth year                 1343039
# gender                     1557663
# dtype: int64

# %% [markdown]
# ## Join July & Aug 2016

# %%
# use concat to append the rows of DF2 to DF1
concat_01 = pd.concat([df_2016_07, df_2016_08], sort=True)
# reset the index of the new DF
concat_01.reset_index()
concat_01.head()
# Out:
#    bikeid  birth year  end station id  end station latitude  \
# 0   17431         NaN             347             40.728846
# 1   24159      1984.0             466             40.743954
# 2   16345      1986.0            3107             40.723117
# 3   25210         NaN             347             40.728846
# 4   15514         NaN             212             40.743349
#
#    end station longitude             end station name  gender  \
# 0             -74.008591  Greenwich St & W Houston St       0
# 1             -73.991449              W 25 St & 6 Ave       1
# 2             -73.952123     Bedford Ave & Nassau Ave       2
# 3             -74.008591  Greenwich St & W Houston St       0
# 4             -74.006818      W 16 St & The High Line       0
#
#    start station id  start station latitude  start station longitude  \
# 0               459               40.746745               -74.007756
# 1               293               40.730287               -73.990765
# ...

# %%
# get # of rows for DF1 + DF2
concat_01_rows = concat_01.count()
print(concat_01_rows)
# Out:
# bikeid                     2937773
# birth year                 2519554
# end station id             2937773
# end station latitude       2937773
# end station longitude      2937773
# end station name           2937773
# gender                     2937773
# start station id           2937773
# start station latitude     2937773
# start station longitude    2937773
# start station name         2937773
# starttime                  2937773
# stoptime                   2937773
# tripduration               2937773
# usertype                   2937773
# dtype: int64

# %% [markdown]
# ## Sept 2016

# %%
# read files into dataframe for DF3
df_2016_09 = pd.read_csv(bike_2016_09)
# show dataframe
df_2016_09.head()
# Out:
#    tripduration          starttime           stoptime  start station id  \
# 0           975  9/1/2016 00:00:02  9/1/2016 00:16:18               312
# 1          1220  9/1/2016 00:00:04  9/1/2016 00:20:25               316
# 2           308  9/1/2016 00:00:19  9/1/2016 00:05:27               479
# 3           250  9/1/2016 00:00:25  9/1/2016 00:04:35               297
# 4           439  9/1/2016 00:00:25  9/1/2016 00:07:45               494
#
#        start station name  start station latitude  start station longitude  \
# 0   Allen St & Stanton St               40.722055               -73.989111
# 1  Fulton St & William St               40.709560               -74.006536
# 2         9 Ave & W 45 St               40.760193               -73.991255
# 3         E 15 St & 3 Ave               40.734232               -73.986923
# 4         W 26 St & 8 Ave               40.747348               -73.997236
#
#    end station id           end station name  end station latitude  \
# ...

# %%
# get # of rows for DF3
df_1609_rows = df_2016_09.count()
print(df_1609_rows)
# Out:
# tripduration               1648856
# starttime                  1648856
# stoptime                   1648856
# start station id           1648856
# start station name         1648856
# start station latitude     1648856
# start station longitude    1648856
# end station id             1648856
# end station name           1648856
# end station latitude       1648856
# end station longitude      1648856
# bikeid                     1648856
# usertype                   1648856
# birth year                 1433341
# gender                     1648856
# dtype: int64

# %% [markdown]
# ## Join Sept 2016 to prev months

# %%
# use concat to append the rows of DF3 to DF1 & DF2
concat_02 = pd.concat([concat_01, df_2016_09], sort=True)
# reset the index of the new DF
concat_02.reset_index()
concat_02.head()
# Out:
#    bikeid  birth year  end station id  end station latitude  \
# 0   17431         NaN             347             40.728846
# 1   24159      1984.0             466             40.743954
# 2   16345      1986.0            3107             40.723117
# 3   25210         NaN             347             40.728846
# 4   15514         NaN             212             40.743349
#
#    end station longitude             end station name  gender  \
# 0             -74.008591  Greenwich St & W Houston St       0
# 1             -73.991449              W 25 St & 6 Ave       1
# 2             -73.952123     Bedford Ave & Nassau Ave       2
# 3             -74.008591  Greenwich St & W Houston St       0
# 4             -74.006818      W 16 St & The High Line       0
#
#    start station id  start station latitude  start station longitude  \
# 0               459               40.746745               -74.007756
# 1               293               40.730287               -73.990765
# ...

# %%
# get # of rows for DF1-DF3
concat_02_rows = concat_02.count()
print(concat_02_rows)
# Out:
# bikeid                     4586629
# birth year                 3952895
# end station id             4586629
# end station latitude       4586629
# end station longitude      4586629
# end station name           4586629
# gender                     4586629
# start station id           4586629
# start station latitude     4586629
# start station longitude    4586629
# start station name         4586629
# starttime                  4586629
# stoptime                   4586629
# tripduration               4586629
# usertype                   4586629
# dtype: int64

# %% [markdown]
# ### The column names in October 2017 change. To be able to concatenate the dataframes together I need to change the data frame column names to match the new October 2017 columns.

# %%
# The columns in OCT 2016 change from lowercase to upper case with spaces
# I need to rename the column headings in the old dataframe (concat_02) to the new format.

concat_02 = concat_02.rename(columns={'tripduration':'Trip Duration', 'starttime':'Start Time', \
                         'stoptime':'Stop Time', 'start station id':'Start Station ID', \
                         'start station name':'Start Station Name', \
                         'start station latitude':'Start Station Latitude', \
                         'start station longitude':'Start Station Longitude', \
                         'end station id':'End Station ID', \
                         'end station name':'End Station Name', \
                         'end station latitude':'End Station Latitude', \
                         'end station longitude':'End Station Longitude', \
                         'bikeid':'Bike ID', \
                         'usertype':'User Type', \
                         'birth year':'Birth Year', \
                         'gender':'Gender'})
# check to see if columns are retitled
concat_02.head()
# Out:
#    Bike ID  Birth Year  End Station ID  End Station Latitude  \
# 0    17431         NaN             347             40.728846
# 1    24159      1984.0             466             40.743954
# 2    16345      1986.0            3107             40.723117
# 3    25210         NaN             347             40.728846
# 4    15514         NaN             212             40.743349
#
#    End Station Longitude             End Station Name  Gender  \
# 0             -74.008591  Greenwich St & W Houston St       0
# 1             -73.991449              W 25 St & 6 Ave       1
# 2             -73.952123     Bedford Ave & Nassau Ave       2
# 3             -74.008591  Greenwich St & W Houston St       0
# 4             -74.006818      W 16 St & The High Line       0
#
#    Start Station ID  Start Station Latitude  Start Station Longitude  \
# 0               459               40.746745               -74.007756
# 1               293               40.730287               -73.990765
# ...

# %% [markdown]
# ### October 2016

# %%
# read files into dataframe for DF4
df_2016_10 = pd.read_csv(bike_2016_10)
df_2016_10.head()
# Out:
#    Trip Duration           Start Time            Stop Time  Start Station ID  \
# 0            328  2016-10-01 00:00:07  2016-10-01 00:05:35               471
# 1            398  2016-10-01 00:00:11  2016-10-01 00:06:49              3147
# 2            430  2016-10-01 00:00:14  2016-10-01 00:07:25               345
# 3            351  2016-10-01 00:00:21  2016-10-01 00:06:12              3307
# 4           2693  2016-10-01 00:00:21  2016-10-01 00:45:15              3428
#
#         Start Station Name  Start Station Latitude  Start Station Longitude  \
# 0  Grand St & Havemeyer St               40.712868               -73.956981
# 1          E 85 St & 3 Ave               40.778012               -73.954071
# 2          W 13 St & 6 Ave               40.736494               -73.997044
# 3   West End Ave & W 94 St               40.794165               -73.974124
# 4          8 Ave & W 16 St               40.740983               -74.001702
#
# ...

# %%
# get # of rows for DF3
df_1610_rows = df_2016_10.count()
print(df_1610_rows)
# Out:
# Trip Duration              1573872
# Start Time                 1573872
# Stop Time                  1573872
# Start Station ID           1573872
# Start Station Name         1573872
# Start Station Latitude     1573872
# Start Station Longitude    1573872
# End Station ID             1573872
# End Station Name           1573872
# End Station Latitude       1573872
# End Station Longitude      1573872
# Bike ID                    1573872
# User Type                  1555923
# Birth Year                 1406424
# Gender                     1573872
# dtype: int64

# %%
# use concat to append the rows of DF2 to DF1
concat_03 = pd.concat([concat_02, df_2016_10], sort=True)
concat_03.reset_index()
concat_03.head()
# Out:
#    Bike ID  Birth Year  End Station ID  End Station Latitude  \
# 0    17431         NaN             347             40.728846
# 1    24159      1984.0             466             40.743954
# 2    16345      1986.0            3107             40.723117
# 3    25210         NaN             347             40.728846
# 4    15514         NaN             212             40.743349
#
#    End Station Longitude             End Station Name  Gender  \
# 0             -74.008591  Greenwich St & W Houston St       0
# 1             -73.991449              W 25 St & 6 Ave       1
# 2             -73.952123     Bedford Ave & Nassau Ave       2
# 3             -74.008591  Greenwich St & W Houston St       0
# 4             -74.006818      W 16 St & The High Line       0
#
#    Start Station ID  Start Station Latitude  Start Station Longitude  \
# 0               459               40.746745               -74.007756
# 1               293               40.730287               -73.990765
# ...

# %%
# get # of rows for DF4
concat_03_rows = concat_03.count()
print(concat_03_rows)
# Out:
# Bike ID                    6160501
# Birth Year                 5359319
# End Station ID             6160501
# End Station Latitude       6160501
# End Station Longitude      6160501
# End Station Name           6160501
# Gender                     6160501
# Start Station ID           6160501
# Start Station Latitude     6160501
# Start Station Longitude    6160501
# Start Station Name         6160501
# Start Time                 6160501
# Stop Time                  6160501
# Trip Duration              6160501
# User Type                  6142552
# dtype: int64

# %% [markdown]
# ### Nov 2016

# %%
# read files into dataframe for DF5
df_2016_11 = pd.read_csv(bike_2016_11)
df_2016_11.head()
# Out:
#    Trip Duration           Start Time            Stop Time  Start Station ID  \
# 0            331  2016-11-01 00:00:08  2016-11-01 00:05:40               324
# 1            740  2016-11-01 00:00:08  2016-11-01 00:12:29               161
# 2            229  2016-11-01 00:00:11  2016-11-01 00:04:00              3074
# 3            155  2016-11-01 00:00:18  2016-11-01 00:02:53              3357
# 4            772  2016-11-01 00:00:23  2016-11-01 00:13:15               346
#
#             Start Station Name  Start Station Latitude  \
# 0      DeKalb Ave & Hudson Ave               40.689888
# 1        LaGuardia Pl & W 3 St               40.729170
# 2  Montrose Ave & Bushwick Ave               40.707678
# 3     W 106 St & Amsterdam Ave               40.800836
# 4          Bank St & Hudson St               40.736529
#
#    Start Station Longitude  End Station ID              End Station Name  \
# 0               -73.981013             419        Carlton Ave & Park Ave
# ...

# %%
# get # of rows for DF4
df_1611_rows = df_2016_11.count()
print(df_1611_rows)
# Out:
# Trip Duration              1196942
# Start Time                 1196942
# Stop Time                  1196942
# Start Station ID           1196942
# Start Station Name         1196942
# Start Station Latitude     1196942
# Start Station Longitude    1196942
# End Station ID             1196942
# End Station Name           1196942
# End Station Latitude       1196942
# End Station Longitude      1196942
# Bike ID                    1196942
# User Type                  1184408
# Birth Year                 1100576
# Gender                     1196942
# dtype: int64

# %%
# use concat to append the rows of DF2 to DF1
concat_04 = pd.concat([concat_03, df_2016_11], sort=True)
concat_04.reset_index()
concat_04.head()
# Out:
#    Bike ID  Birth Year  End Station ID  End Station Latitude  \
# 0    17431         NaN             347             40.728846
# 1    24159      1984.0             466             40.743954
# 2    16345      1986.0            3107             40.723117
# 3    25210         NaN             347             40.728846
# 4    15514         NaN             212             40.743349
#
#    End Station Longitude             End Station Name  Gender  \
# 0             -74.008591  Greenwich St & W Houston St       0
# 1             -73.991449              W 25 St & 6 Ave       1
# 2             -73.952123     Bedford Ave & Nassau Ave       2
# 3             -74.008591  Greenwich St & W Houston St       0
# 4             -74.006818      W 16 St & The High Line       0
#
#    Start Station ID  Start Station Latitude  Start Station Longitude  \
# 0               459               40.746745               -74.007756
# 1               293               40.730287               -73.990765
# ...

# %%
# get # of rows for DF4
concat_04_rows = concat_04.count()
print(concat_04_rows)
# Out:
# Bike ID                    7357443
# Birth Year                 6459895
# End Station ID             7357443
# End Station Latitude       7357443
# End Station Longitude      7357443
# End Station Name           7357443
# Gender                     7357443
# Start Station ID           7357443
# Start Station Latitude     7357443
# Start Station Longitude    7357443
# Start Station Name         7357443
# Start Time                 7357443
# Stop Time                  7357443
# Trip Duration              7357443
# User Type                  7326960
# dtype: int64

# %% [markdown]
# ### Jan 2017

# %%
# read files into dataframe for DF5
df_2017_01 = pd.read_csv(bike_2017_01)
df_2017_01.head()
# Out:
#    Trip Duration           Start Time            Stop Time  Start Station ID  \
# 0            680  2017-01-01 00:00:21  2017-01-01 00:11:41              3226
# 1           1282  2017-01-01 00:00:45  2017-01-01 00:22:08              3263
# 2            648  2017-01-01 00:00:57  2017-01-01 00:11:46              3143
# 3            631  2017-01-01 00:01:10  2017-01-01 00:11:42              3143
# 4            621  2017-01-01 00:01:25  2017-01-01 00:11:47              3143
#
#             Start Station Name  Start Station Latitude  \
# 0  W 82 St & Central Park West               40.782750
# 1       Cooper Square & E 7 St               40.729236
# 2              5 Ave & E 78 St               40.776829
# 3              5 Ave & E 78 St               40.776829
# 4              5 Ave & E 78 St               40.776829
#
#    Start Station Longitude  End Station ID             End Station Name  \
# 0               -73.971370            3165  Central Park West & W 72 St
# ...

# %%
# get # of rows for DF5
df_1701_rows = df_2017_01.count()
print(df_1701_rows)
# Out:
# Trip Duration              726676
# Start Time                 726676
# Stop Time                  726676
# Start Station ID           726676
# Start Station Name         726676
# Start Station Latitude     726676
# Start Station Longitude    726676
# End Station ID             726676
# End Station Name           726676
# End Station Latitude       726676
# End Station Longitude      726676
# Bike ID                    726676
# User Type                  723483
# Birth Year                 697600
# Gender                     726676
# dtype: int64

# %%
# use concat to append the rows of DF5 to DF4
concat_05 = pd.concat([concat_04, df_2017_01], sort=True)
concat_05.reset_index()
concat_05.head()
# Out:
#    Bike ID  Birth Year  End Station ID  End Station Latitude  \
# 0    17431         NaN             347             40.728846
# 1    24159      1984.0             466             40.743954
# 2    16345      1986.0            3107             40.723117
# 3    25210         NaN             347             40.728846
# 4    15514         NaN             212             40.743349
#
#    End Station Longitude             End Station Name  Gender  \
# 0             -74.008591  Greenwich St & W Houston St       0
# 1             -73.991449              W 25 St & 6 Ave       1
# 2             -73.952123     Bedford Ave & Nassau Ave       2
# 3             -74.008591  Greenwich St & W Houston St       0
# 4             -74.006818      W 16 St & The High Line       0
#
#    Start Station ID  Start Station Latitude  Start Station Longitude  \
# 0               459               40.746745               -74.007756
# 1               293               40.730287               -73.990765
# ...

# %%
# get # of rows for DF5
concat_05_rows = concat_05.count()
print(concat_05_rows)
# Out:
# Bike ID                    8084119
# Birth Year                 7157495
# End Station ID             8084119
# End Station Latitude       8084119
# End Station Longitude      8084119
# End Station Name           8084119
# Gender                     8084119
# Start Station ID           8084119
# Start Station Latitude     8084119
# Start Station Longitude    8084119
# Start Station Name         8084119
# Start Time                 8084119
# Stop Time                  8084119
# Trip Duration              8084119
# User Type                  8050443
# dtype: int64

# %% [markdown]
# ### Feb 17

# %%
# read files into dataframe for DF5
df_2017_02 = pd.read_csv(bike_2017_02)
df_2017_02.head()
# Out:
#    Trip Duration           Start Time            Stop Time  Start Station ID  \
# 0           1087  2017-02-01 00:00:13  2017-02-01 00:18:20               345
# 1            704  2017-02-01 00:00:31  2017-02-01 00:12:15              3295
# 2            212  2017-02-01 00:00:34  2017-02-01 00:04:06               336
# 3           1140  2017-02-01 00:00:44  2017-02-01 00:19:44               484
# 4            320  2017-02-01 00:00:42  2017-02-01 00:06:02               490
#
#             Start Station Name  Start Station Latitude  \
# 0              W 13 St & 6 Ave               40.736494
# 1     Central Park W & W 96 St               40.791270
# 2  Sullivan St & Washington Sq               40.730477
# 3              W 44 St & 5 Ave               40.755003
# 4              8 Ave & W 33 St               40.751551
#
#    Start Station Longitude  End Station ID          End Station Name  \
# 0               -73.997044             305           E 58 St & 3 Ave
# ...

# %%
# use concat to append the rows of DF5 to DF4
concat_06 = pd.concat([concat_05, df_2017_02], sort=True)
concat_06.reset_index()
concat_06.head()
# Out:
#    Bike ID  Birth Year  End Station ID  End Station Latitude  \
# 0    17431         NaN             347             40.728846
# 1    24159      1984.0             466             40.743954
# 2    16345      1986.0            3107             40.723117
# 3    25210         NaN             347             40.728846
# 4    15514         NaN             212             40.743349
#
#    End Station Longitude             End Station Name  Gender  \
# 0             -74.008591  Greenwich St & W Houston St       0
# 1             -73.991449              W 25 St & 6 Ave       1
# 2             -73.952123     Bedford Ave & Nassau Ave       2
# 3             -74.008591  Greenwich St & W Houston St       0
# 4             -74.006818      W 16 St & The High Line       0
#
#    Start Station ID  Start Station Latitude  Start Station Longitude  \
# 0               459               40.746745               -74.007756
# 1               293               40.730287               -73.990765
# ...

# %%
# get # of rows for DF5
concat_06_rows = concat_06.count()
print(concat_06_rows)
# Out:
# Bike ID                    8875766
# Birth Year                 7899819
# End Station ID             8875766
# End Station Latitude       8875766
# End Station Longitude      8875766
# End Station Name           8875766
# Gender                     8875766
# Start Station ID           8875766
# Start Station Latitude     8875766
# Start Station Longitude    8875766
# Start Station Name         8875766
# Start Time                 8875766
# Stop Time                  8875766
# Trip Duration              8875766
# User Type                  8834510
# dtype: int64

# %% [markdown]
# ### Mar 17

# %%
# read files into dataframe for DF5
df_2017_03 = pd.read_csv(bike_2017_03)
df_2017_03.head()
# Out:
#    Trip Duration           Start Time            Stop Time  Start Station ID  \
# 0           1893  2017-03-01 00:00:32  2017-03-01 00:32:06              2009
# 1            223  2017-03-01 00:01:09  2017-03-01 00:04:53               127
# 2           1665  2017-03-01 00:01:27  2017-03-01 00:29:12               174
# 3            100  2017-03-01 00:01:29  2017-03-01 00:03:10               316
# 4           1229  2017-03-01 00:01:33  2017-03-01 00:22:02               536
#
#          Start Station Name  Start Station Latitude  Start Station Longitude  \
# 0  Catherine St & Monroe St               40.711174               -73.996826
# 1     Barrow St & Hudson St               40.731724               -74.006744
# 2           E 25 St & 1 Ave               40.738177               -73.977387
# 3    Fulton St & William St               40.709560               -74.006536
# 4           1 Ave & E 30 St               40.741444               -73.975361
#
# ...

# %%
# use concat to append the rows of DF5 to DF4
concat_07 = pd.concat([concat_06, df_2017_03], sort=True)
concat_07.reset_index()
concat_07.head()
# Out:
#    Bike ID  Birth Year  End Station ID  End Station Latitude  \
# 0    17431         NaN             347             40.728846
# 1    24159      1984.0             466             40.743954
# 2    16345      1986.0            3107             40.723117
# 3    25210         NaN             347             40.728846
# 4    15514         NaN             212             40.743349
#
#    End Station Longitude             End Station Name  Gender  \
# 0             -74.008591  Greenwich St & W Houston St       0
# 1             -73.991449              W 25 St & 6 Ave       1
# 2             -73.952123     Bedford Ave & Nassau Ave       2
# 3             -74.008591  Greenwich St & W Houston St       0
# 4             -74.006818      W 16 St & The High Line       0
#
#    Start Station ID  Start Station Latitude  Start Station Longitude  \
# 0               459               40.746745               -74.007756
# 1               293               40.730287               -73.990765
# ...

# %%
# get # of rows for DF5
concat_07_rows = concat_07.count()
print(concat_07_rows)
# Out:
# Bike ID                    9603431
# Birth Year                 8594638
# End Station ID             9603431
# End Station Latitude       9603431
# End Station Longitude      9603431
# End Station Name           9603431
# Gender                     9603431
# Start Station ID           9603431
# Start Station Latitude     9603431
# Start Station Longitude    9603431
# Start Station Name         9603431
# Start Time                 9603431
# Stop Time                  9603431
# Trip Duration              9603431
# User Type                  9557039
# dtype: int64

# %% [markdown]
# ### Steps to reduce file size

# %%
# Drop rows where any data is missing
concat_07 = concat_07.dropna(how='any')

# %%
# Reset index, Verify dropped rows
concat_07.reset_index()
concat_07.count()
# Out:
# Bike ID                    8548326
# Birth Year                 8548326
# End Station ID             8548326
# End Station Latitude       8548326
# End Station Longitude      8548326
# End Station Name           8548326
# Gender                     8548326
# Start Station ID           8548326
# Start Station Latitude     8548326
# Start Station Longitude    8548326
# Start Station Name         8548326
# Start Time                 8548326
# Stop Time                  8548326
# Trip Duration              8548326
# User Type                  8548326
# dtype: int64

# %%
# review data types to see if we can optimize the columns
concat_07.dtypes
# Out:
# Bike ID                      int64
# Birth Year                 float64
# End Station ID               int64
# End Station Latitude       float64
# End Station Longitude      float64
# End Station Name            object
# Gender                       int64
# Start Station ID             int64
# Start Station Latitude     float64
# Start Station Longitude    float64
# Start Station Name          object
# Start Time                  object
# Stop Time                   object
# Trip Duration                int64
# User Type                   object
# dtype: object

# %%
# see if I can change BIKE ID to smaller integer
concat_07['Bike ID'].min()
# Out:
# 14529

# %%
# see if I can change BIKE ID to smaller integer
concat_07['Bike ID'].max()
# Out:
# 29196

# %%
# change Bike ID from int64 to int32
concat_07['Bike ID'] = concat_07['Bike ID'].astype(np.int32)

# %%
# confirm change to DF
concat_07.dtypes
# Out:
# Bike ID                      int32
# Birth Year                 float64
# End Station ID               int64
# End Station Latitude       float64
# End Station Longitude      float64
# End Station Name            object
# Gender                       int64
# Start Station ID             int64
# Start Station Latitude     float64
# Start Station Longitude    float64
# Start Station Name          object
# Start Time                  object
# Stop Time                   object
# Trip Duration                int64
# User Type                   object
# dtype: object

# %%
# see if I can change End Station ID to smaller integer
concat_07['End Station ID'].min()
# Out:
# 72

# %%
# see if I can change End Station ID to smaller integer
concat_07['End Station ID'].max()
# Out:
# 3456

# %%
# change End Station ID from int64 to int16
concat_07['End Station ID'] = concat_07['End Station ID'].astype(np.int16)

# %%
# confirm change to DF
concat_07.dtypes
# Out:
# Bike ID                      int32
# Birth Year                 float64
# End Station ID               int16
# End Station Latitude       float64
# End Station Longitude      float64
# End Station Name            object
# Gender                       int64
# Start Station ID             int64
# Start Station Latitude     float64
# Start Station Longitude    float64
# Start Station Name          object
# Start Time                  object
# Stop Time                   object
# Trip Duration                int64
# User Type                   object
# dtype: object

# %%
# change Start Station ID from int64 to int16
concat_07['Start Station ID'] = concat_07['Start Station ID'].astype(np.int16)

# %%
# confirm change to DF
concat_07.dtypes
# Out:
# Bike ID                      int32
# Birth Year                 float64
# End Station ID               int16
# End Station Latitude       float64
# End Station Longitude      float64
# End Station Name            object
# Gender                       int64
# Start Station ID             int16
# Start Station Latitude     float64
# Start Station Longitude    float64
# Start Station Name          object
# Start Time                  object
# Stop Time                   object
# Trip Duration                int64
# User Type                   object
# dtype: object

# %%
# see if I can change Gender to smaller integer
concat_07['Gender'].min()
# Out:
# 0

# %%
# see if I can change Gender to smaller integer
concat_07['Gender'].max()
# Out:
# 2

# %%
# change Gender from int64 to byte
concat_07['Gender'] = concat_07['Gender'].astype(np.byte)

# %%
# confirm change to DF
concat_07.dtypes
# Out:
# Bike ID                      int32
# Birth Year                 float64
# End Station ID               int16
# End Station Latitude       float64
# End Station Longitude      float64
# End Station Name            object
# Gender                        int8
# Start Station ID             int16
# Start Station Latitude     float64
# Start Station Longitude    float64
# Start Station Name          object
# Start Time                  object
# Stop Time                   object
# Trip Duration                int64
# User Type                   object
# dtype: object

# %%
# see if I can change Trip Duration to smaller integer
concat_07['Trip Duration'].min()
# Out:
# 61

# %%
# see if I can change Trip Duration to smaller integer ... this is suspect
concat_07['Trip Duration'].max()
# Out:
# 8933552

# %%
# histogram for Trip Duration ... and this is useless
concat_07.hist(column='Trip Duration', bins=10)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001EE357B3C50>]],
#       dtype=object)

# %%
# value counts for trip duration
concat_07['Trip Duration'].value_counts()
# Out:
# 356        10955
# 350        10944
# 360        10926
# 357        10907
# 377        10905
# 334        10904
# 348        10873
# 325        10872
# 380        10866
# 337        10859
# 323        10855
# 371        10842
# 369        10837
# 372        10835
# 319        10833
# 368        10831
# 331        10828
# 376        10827
# 333        10823
# 344        10820
# 345        10817
# 343        10815
# 381        10800
# 318        10787
# 361        10786
# 390        10784
# 365        10781
# 367        10779
# 316        10778
# 366        10777
#            ...
# 29133          1
# 45535          1
# 2176484        1
# 37328          1
# 12740          1
# 20939          1
# 12728          1
# 61859          1
# 12732          1
# 12751          1
# 53718          1
# 61945          1
# 37327          1
# 20973          1
# 29163          1
# 37360          1
# 12772          1
# 53755          1
# 12775          1
# 70140          1
# 12753          1
# ...

# %%
# remove all rows Trip Duration > 86,400 (24 hours)
# get names of indexes for Trip Duration column where TD > 86,400
indexNames = concat_07[concat_07['Trip Duration'] > 86400].index
concat_07.drop(indexNames, inplace=True)

# %%
# check max Trip Duration
concat_07['Trip Duration'].max()
# Out:
# 86322

# %%
# Reset index, Verify dropped rows
concat_07.reset_index()
concat_07.count()
# Out:
# Bike ID                    8543067
# Birth Year                 8543067
# End Station ID             8543067
# End Station Latitude       8543067
# End Station Longitude      8543067
# End Station Name           8543067
# Gender                     8543067
# Start Station ID           8543067
# Start Station Latitude     8543067
# Start Station Longitude    8543067
# Start Station Name         8543067
# Start Time                 8543067
# Stop Time                  8543067
# Trip Duration              8543067
# User Type                  8543067
# dtype: int64

# %%
# confirm change to DF
concat_07.dtypes
# Out:
# Bike ID                      int32
# Birth Year                 float64
# End Station ID               int16
# End Station Latitude       float64
# End Station Longitude      float64
# End Station Name            object
# Gender                        int8
# Start Station ID             int16
# Start Station Latitude     float64
# Start Station Longitude    float64
# Start Station Name          object
# Start Time                  object
# Stop Time                   object
# Trip Duration                int64
# User Type                   object
# dtype: object

# %%
# now change Trip Duration from int64 to int32
concat_07['Trip Duration'] = concat_07['Trip Duration'].astype(np.int32)

# %%
# confirm change to DF
concat_07.dtypes
# Out:
# Bike ID                      int32
# Birth Year                 float64
# End Station ID               int16
# End Station Latitude       float64
# End Station Longitude      float64
# End Station Name            object
# Gender                        int8
# Start Station ID             int16
# Start Station Latitude     float64
# Start Station Longitude    float64
# Start Station Name          object
# Start Time                  object
# Stop Time                   object
# Trip Duration                int32
# User Type                   object
# dtype: object

# %%
# see if I can change Birth Year to smaller integer
concat_07['Birth Year'].min()
# Out:
# 1885.0

# %%
# see if I can change Birth Year to smaller integer
concat_07['Birth Year'].max()
# Out:
# 2001.0

# %%
# look at table
concat_07.head()
# Out:
#    Bike ID  Birth Year  End Station ID  End Station Latitude  \
# 1    24159      1984.0             466             40.743954
# 2    16345      1986.0            3107             40.723117
# 5    15444      1991.0             347             40.728846
# 6    14676      1989.0             250             40.724561
# 7    25755      1989.0             284             40.739017
#
#    End Station Longitude             End Station Name  Gender  \
# 1             -73.991449              W 25 St & 6 Ave       1
# 2             -73.952123     Bedford Ave & Nassau Ave       2
# 5             -74.008591  Greenwich St & W Houston St       1
# 6             -73.995653   Lafayette St & Jersey St N       1
# 7             -74.002638        Greenwich Ave & 8 Ave       1
#
#    Start Station ID  Start Station Latitude  Start Station Longitude  \
# 1               293               40.730287               -73.990765
# 2              3090               40.717746               -73.956001
# ...

# %%
# export to csv
concat_07.to_csv("concat_07_201607_201703.csv", index=False, header=True)
