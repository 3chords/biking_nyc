# %%
# dependencies

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import scipy.stats as stats

# %% [markdown]
# ### Bring in the CSVs going back 3 years

# %%
# load the files

folder = "extracted_csvs/"
rest_of_file = "-citibike-tripdata.csv"

#bike_2016_07 = folder + "201607" + rest_of_file
#bike_2016_08 = folder + "201608" + rest_of_file
#bike_2016_09 = folder + "201609" + rest_of_file
#bike_2016_10 = folder + "201610" + rest_of_file
#bike_2016_11 = folder + "201611" + rest_of_file
#bike_2016_12 = folder + "201612" + rest_of_file
#bike_2017_01 = folder + "201701" + rest_of_file
#bike_2017_02 = folder + "201702" + rest_of_file
#bike_2017_03 = folder + "201703" + rest_of_file
bike_2017_04 = folder + "201704" + rest_of_file
bike_2017_05 = folder + "201705" + rest_of_file
bike_2017_06 = folder + "201706" + rest_of_file
bike_2017_07 = folder + "201707" + rest_of_file
bike_2017_08 = folder + "201708" + rest_of_file
bike_2017_09 = folder + "201709" + rest_of_file
bike_2017_10 = folder + "201710" + rest_of_file
bike_2017_11 = folder + "201711" + rest_of_file
bike_2017_12 = folder + "201712" + rest_of_file
#bike_2018_01 = folder + "201801" + rest_of_file
#bike_2018_02 = folder + "201802" + rest_of_file
#bike_2018_03 = folder + "201803" + rest_of_file
#bike_2018_04 = folder + "201804" + rest_of_file
#bike_2018_05 = folder + "201805" + rest_of_file
#bike_2018_06 = folder + "201806" + rest_of_file
#bike_2018_07 = folder + "201807" + rest_of_file
#bike_2018_08 = folder + "201808" + rest_of_file
#bike_2018_09 = folder + "201809" + rest_of_file
#bike_2018_10 = folder + "201810" + rest_of_file
#bike_2018_11 = folder + "201811" + rest_of_file
#bike_2018_12 = folder + "201812" + rest_of_file
#bike_2019_01 = folder + "201901" + rest_of_file
#bike_2019_02 = folder + "201902" + rest_of_file
#bike_2019_03 = folder + "201903" + rest_of_file
#bike_2019_04 = folder + "201904" + rest_of_file
#bike_2019_05 = folder + "201905" + rest_of_file
#bike_2019_06 = folder + "201906" + rest_of_file
#bike_2019_07 = folder + "201907" + rest_of_file

# %% [markdown]
# ### Apr 17 - Dec 17, same column names

# %%
# read files into dataframe for DF5
df_2017_04 = pd.read_csv(bike_2017_04)
df_2017_04.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           195  2017-04-01 00:00:58  2017-04-01 00:04:14               217
# 1           585  2017-04-01 00:01:54  2017-04-01 00:11:40               490
# 2           665  2017-04-01 00:01:56  2017-04-01 00:13:01               504
# 3           262  2017-04-01 00:02:24  2017-04-01 00:06:47               445
# 4           134  2017-04-01 00:02:36  2017-04-01 00:04:50              3423
#
#                 start station name  start station latitude  \
# 0                    Old Fulton St               40.702772
# 1                  8 Ave & W 33 St               40.751551
# 2                  1 Ave & E 16 St               40.732219
# 3               E 10 St & Avenue A               40.727408
# 4  West Drive & Prospect Park West               40.661063
#
#    start station longitude  end station id           end station name  \
# 0               -73.993836             430           York St & Jay St
# ...

# %%
# get # of rows
df_1704_rows = df_2017_04.count()
print(df_1704_rows)
# Out:
# tripduration               1315404
# starttime                  1315404
# stoptime                   1315404
# start station id           1315404
# start station name         1315404
# start station latitude     1315404
# start station longitude    1315404
# end station id             1315404
# end station name           1315404
# end station latitude       1315404
# end station longitude      1315404
# bikeid                     1315404
# usertype                   1315404
# birth year                 1146732
# gender                     1315404
# dtype: int64

# %%
# read files into dataframe for DF5
df_2017_05 = pd.read_csv(bike_2017_05)
df_2017_05.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           254  2017-05-01 00:00:13  2017-05-01 00:04:27               511
# 1           248  2017-05-01 00:00:19  2017-05-01 00:04:28               511
# 2          1120  2017-05-01 00:00:19  2017-05-01 00:19:00               242
# 3           212  2017-05-01 00:00:24  2017-05-01 00:03:56               168
# 4           686  2017-05-01 00:00:29  2017-05-01 00:11:55               494
#
#            start station name  start station latitude  \
# 0          E 14 St & Avenue B               40.729387
# 1          E 14 St & Avenue B               40.729387
# 2  Carlton Ave & Flushing Ave               40.697787
# 3             W 18 St & 6 Ave               40.739713
# 4             W 26 St & 8 Ave               40.747348
#
#    start station longitude  end station id          end station name  \
# 0               -73.977724             394         E 9 St & Avenue C
# ...

# %%
# get # of rows
df_1705_rows = df_2017_05.count()
print(df_1705_rows)
# Out:
# tripduration               1523268
# starttime                  1523268
# stoptime                   1523268
# start station id           1523268
# start station name         1523268
# start station latitude     1523268
# start station longitude    1523268
# end station id             1523268
# end station name           1523268
# end station latitude       1523268
# end station longitude      1523268
# bikeid                     1523268
# usertype                   1523268
# birth year                 1350445
# gender                     1523268
# dtype: int64

# %%
# use concat to append the rows of DF2 to DF1
concat_08 = pd.concat([df_2017_04, df_2017_05], sort=True)
# reset the index of the new DF
concat_08.reset_index()
concat_08.head()
# Out:
#    bikeid  birth year  end station id  end station latitude  \
# 0   25454      1966.0             430             40.701485
# 1   25930      1995.0            3158             40.771639
# 2   27110      1987.0             412             40.715816
# 3   28392      1961.0             411             40.722281
# 4   19316      1967.0            3300             40.665147
#
#    end station longitude           end station name  gender  start station id  \
# 0             -73.986569           York St & Jay St       1               217
# 1             -73.982614         W 63 St & Broadway       1               490
# 2             -73.994224      Forsyth St & Canal St       1               504
# 3             -73.976687          E 6 St & Avenue D       1               445
# 4             -73.976376  Prospect Park West & 8 St       2              3423
#
#    start station latitude  start station longitude  \
# 0               40.702772               -73.993836
# ...

# %%
# get # of rows for concatenate
concat_08_rows = concat_08.count()
print(concat_08_rows)
# Out:
# bikeid                     2838672
# birth year                 2497177
# end station id             2838672
# end station latitude       2838672
# end station longitude      2838672
# end station name           2838672
# gender                     2838672
# start station id           2838672
# start station latitude     2838672
# start station longitude    2838672
# start station name         2838672
# starttime                  2838672
# stoptime                   2838672
# tripduration               2838672
# usertype                   2838672
# dtype: int64

# %%
# read files into dataframe for June 2017
df_2017_06 = pd.read_csv(bike_2017_06)
df_2017_06.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0          1397  2017-06-01 00:00:02  2017-06-01 00:23:19               515
# 1          1103  2017-06-01 00:00:13  2017-06-01 00:18:37               488
# 2          1810  2017-06-01 00:00:20  2017-06-01 00:30:31               461
# 3          1760  2017-06-01 00:00:24  2017-06-01 00:29:45              2009
# 4          2165  2017-06-01 00:00:33  2017-06-01 00:36:38               360
#
#          start station name  start station latitude  start station longitude  \
# 0          W 43 St & 10 Ave               40.760094               -73.994618
# 1           W 39 St & 9 Ave               40.756458               -73.993722
# 2           E 20 St & 2 Ave               40.735877               -73.982050
# 3  Catherine St & Monroe St               40.711174               -73.996826
# 4      William St & Pine St               40.707179               -74.008873
#
# ...

# %%
# get # of rows
df_1706_rows = df_2017_06.count()
print(df_1706_rows)
# Out:
# tripduration               1731594
# starttime                  1731594
# stoptime                   1731594
# start station id           1731594
# start station name         1731594
# start station latitude     1731594
# start station longitude    1731594
# end station id             1731594
# end station name           1731594
# end station latitude       1731594
# end station longitude      1731594
# bikeid                     1731594
# usertype                   1731594
# birth year                 1539162
# gender                     1731594
# dtype: int64

# %%
# use concat to append the June 2017 to prev concat
concat_09 = pd.concat([concat_08, df_2017_06], sort=True)
# reset the index of the new DF
concat_09.reset_index()
concat_09.head()
# Out:
#    bikeid  birth year  end station id  end station latitude  \
# 0   25454      1966.0             430             40.701485
# 1   25930      1995.0            3158             40.771639
# 2   27110      1987.0             412             40.715816
# 3   28392      1961.0             411             40.722281
# 4   19316      1967.0            3300             40.665147
#
#    end station longitude           end station name  gender  start station id  \
# 0             -73.986569           York St & Jay St       1               217
# 1             -73.982614         W 63 St & Broadway       1               490
# 2             -73.994224      Forsyth St & Canal St       1               504
# 3             -73.976687          E 6 St & Avenue D       1               445
# 4             -73.976376  Prospect Park West & 8 St       2              3423
#
#    start station latitude  start station longitude  \
# 0               40.702772               -73.993836
# ...

# %%
# get # of rows for concatenate
concat_09_rows = concat_09.count()
print(concat_09_rows)
# Out:
# bikeid                     4570266
# birth year                 4036339
# end station id             4570266
# end station latitude       4570266
# end station longitude      4570266
# end station name           4570266
# gender                     4570266
# start station id           4570266
# start station latitude     4570266
# start station longitude    4570266
# start station name         4570266
# starttime                  4570266
# stoptime                   4570266
# tripduration               4570266
# usertype                   4570266
# dtype: int64

# %%
# read files into dataframe for july 2017
df_2017_07 = pd.read_csv(bike_2017_07)
df_2017_07.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           364  2017-07-01 00:00:00  2017-07-01 00:06:05               539
# 1          2142  2017-07-01 00:00:03  2017-07-01 00:35:46               293
# 2           328  2017-07-01 00:00:08  2017-07-01 00:05:37              3242
# 3          2530  2017-07-01 00:00:11  2017-07-01 00:42:22              2002
# 4          2534  2017-07-01 00:00:15  2017-07-01 00:42:29              2002
#
#                start station name  start station latitude  \
# 0  Metropolitan Ave & Bedford Ave               40.715348
# 1           Lafayette St & E 8 St               40.730207
# 2      Schermerhorn St & Court St               40.691029
# 3    Wythe Ave & Metropolitan Ave               40.716887
# 4    Wythe Ave & Metropolitan Ave               40.716887
#
#    start station longitude  end station id          end station name  \
# 0               -73.960241            3107  Bedford Ave & Nassau Ave
# ...

# %%
# get # of rows
df_1707_rows = df_2017_07.count()
print(df_1707_rows)
# Out:
# tripduration               1735599
# starttime                  1735599
# stoptime                   1735599
# start station id           1735599
# start station name         1735599
# start station latitude     1735599
# start station longitude    1735599
# end station id             1735599
# end station name           1735599
# end station latitude       1735599
# end station longitude      1735599
# bikeid                     1735599
# usertype                   1735599
# birth year                 1507003
# gender                     1735599
# dtype: int64

# %%
# use concat to append the rows of DF2 to DF1
concat_10 = pd.concat([concat_09, df_2017_07], sort=True)
# reset the index of the new DF
concat_10.reset_index()
concat_10.head()
# Out:
#    bikeid  birth year  end station id  end station latitude  \
# 0   25454      1966.0             430             40.701485
# 1   25930      1995.0            3158             40.771639
# 2   27110      1987.0             412             40.715816
# 3   28392      1961.0             411             40.722281
# 4   19316      1967.0            3300             40.665147
#
#    end station longitude           end station name  gender  start station id  \
# 0             -73.986569           York St & Jay St       1               217
# 1             -73.982614         W 63 St & Broadway       1               490
# 2             -73.994224      Forsyth St & Canal St       1               504
# 3             -73.976687          E 6 St & Avenue D       1               445
# 4             -73.976376  Prospect Park West & 8 St       2              3423
#
#    start station latitude  start station longitude  \
# 0               40.702772               -73.993836
# ...

# %%
# get # of rows for concatenate
concat_10_rows = concat_10.count()
print(concat_10_rows)
# Out:
# bikeid                     6305865
# birth year                 5543342
# end station id             6305865
# end station latitude       6305865
# end station longitude      6305865
# end station name           6305865
# gender                     6305865
# start station id           6305865
# start station latitude     6305865
# start station longitude    6305865
# start station name         6305865
# starttime                  6305865
# stoptime                   6305865
# tripduration               6305865
# usertype                   6305865
# dtype: int64

# %%
# read files into dataframe for Aug 2017
df_2017_08 = pd.read_csv(bike_2017_08)
df_2017_08.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0          2110  2017-08-01 00:00:00  2017-08-01 00:35:11               470
# 1           160  2017-08-01 00:00:10  2017-08-01 00:02:51               348
# 2          1644  2017-08-01 00:00:17  2017-08-01 00:27:41              3165
# 3           323  2017-08-01 00:00:27  2017-08-01 00:05:51               389
# 4           109  2017-08-01 00:00:41  2017-08-01 00:02:31              3145
#
#             start station name  start station latitude  \
# 0              W 20 St & 8 Ave               40.743453
# 1       W Broadway & Spring St               40.724910
# 2  Central Park West & W 72 St               40.775794
# 3          Broadway & Berry St               40.710446
# 4           E 84 St & Park Ave               40.778627
#
#    start station longitude  end station id              end station name  \
# 0               -74.000040            3289       W 90 St & Amsterdam Ave
# ...

# %%
# use concat to append the rows
concat_11 = pd.concat([concat_10, df_2017_08], sort=True)
# reset the index of the new DF
concat_11.reset_index()
concat_11.head()
# Out:
#    bikeid  birth year  end station id  end station latitude  \
# 0   25454      1966.0             430             40.701485
# 1   25930      1995.0            3158             40.771639
# 2   27110      1987.0             412             40.715816
# 3   28392      1961.0             411             40.722281
# 4   19316      1967.0            3300             40.665147
#
#    end station longitude           end station name  gender  start station id  \
# 0             -73.986569           York St & Jay St       1               217
# 1             -73.982614         W 63 St & Broadway       1               490
# 2             -73.994224      Forsyth St & Canal St       1               504
# 3             -73.976687          E 6 St & Avenue D       1               445
# 4             -73.976376  Prospect Park West & 8 St       2              3423
#
#    start station latitude  start station longitude  \
# 0               40.702772               -73.993836
# ...

# %%
# read files into dataframe for Sept 2017
df_2017_09 = pd.read_csv(bike_2017_09)
df_2017_09.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           362  2017-09-01 00:00:17  2017-09-01 00:06:19              3331
# 1           188  2017-09-01 00:00:21  2017-09-01 00:03:30              3101
# 2           305  2017-09-01 00:00:25  2017-09-01 00:05:30              3140
# 3           223  2017-09-01 00:00:52  2017-09-01 00:04:36               236
# 4           758  2017-09-01 00:01:01  2017-09-01 00:13:40              3427
#
#          start station name  start station latitude  start station longitude  \
# 0   Riverside Dr & W 104 St               40.801343               -73.971146
# 1     N 12 St & Bedford Ave               40.720798               -73.954847
# 2           1 Ave & E 78 St               40.771404               -73.953517
# 3       St Marks Pl & 2 Ave               40.728419               -73.987140
# 4  Lafayette St & Jersey St               40.724305               -73.996010
#
# ...

# %%
# use concat to append the rows
concat_12 = pd.concat([concat_11, df_2017_09], sort=True)
# reset the index of the new DF
concat_12.reset_index()
concat_12.head()
# Out:
#    bikeid  birth year  end station id  end station latitude  \
# 0   25454      1966.0             430             40.701485
# 1   25930      1995.0            3158             40.771639
# 2   27110      1987.0             412             40.715816
# 3   28392      1961.0             411             40.722281
# 4   19316      1967.0            3300             40.665147
#
#    end station longitude           end station name  gender  start station id  \
# 0             -73.986569           York St & Jay St       1               217
# 1             -73.982614         W 63 St & Broadway       1               490
# 2             -73.994224      Forsyth St & Canal St       1               504
# 3             -73.976687          E 6 St & Avenue D       1               445
# 4             -73.976376  Prospect Park West & 8 St       2              3423
#
#    start station latitude  start station longitude  \
# 0               40.702772               -73.993836
# ...

# %%
# read files into dataframe for Oct 2017
df_2017_10 = pd.read_csv(bike_2017_10)
df_2017_10.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           457  2017-10-01 00:00:00  2017-10-01 00:07:38               479
# 1          6462  2017-10-01 00:00:20  2017-10-01 01:48:03               279
# 2           761  2017-10-01 00:00:27  2017-10-01 00:13:09               504
# 3          1193  2017-10-01 00:00:29  2017-10-01 00:20:22              3236
# 4          2772  2017-10-01 00:00:32  2017-10-01 00:46:44              2006
#
#        start station name  start station latitude  start station longitude  \
# 0         9 Ave & W 45 St               40.760193               -73.991255
# 1    Peck Slip & Front St               40.707873               -74.001670
# 2         1 Ave & E 16 St               40.732219               -73.981656
# 3      W 42 St & Dyer Ave               40.758985               -73.993800
# 4  Central Park S & 6 Ave               40.765909               -73.976342
#
# ...

# %%
# use concat to append the rows
concat_13 = pd.concat([concat_12, df_2017_10], sort=True)
# reset the index of the new DF
concat_13.reset_index()
concat_13.head()
# Out:
#    bikeid  birth year  end station id  end station latitude  \
# 0   25454      1966.0             430             40.701485
# 1   25930      1995.0            3158             40.771639
# 2   27110      1987.0             412             40.715816
# 3   28392      1961.0             411             40.722281
# 4   19316      1967.0            3300             40.665147
#
#    end station longitude           end station name  gender  start station id  \
# 0             -73.986569           York St & Jay St       1               217
# 1             -73.982614         W 63 St & Broadway       1               490
# 2             -73.994224      Forsyth St & Canal St       1               504
# 3             -73.976687          E 6 St & Avenue D       1               445
# 4             -73.976376  Prospect Park West & 8 St       2              3423
#
#    start station latitude  start station longitude  \
# 0               40.702772               -73.993836
# ...

# %%
# read files into dataframe for Nov 2011
df_2017_11 = pd.read_csv(bike_2017_11)
df_2017_11.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           297  2017-11-01 00:00:01  2017-11-01 00:04:59               418
# 1           269  2017-11-01 00:00:01  2017-11-01 00:04:30              3556
# 2           285  2017-11-01 00:00:04  2017-11-01 00:04:50               275
# 3           478  2017-11-01 00:00:13  2017-11-01 00:08:11              3545
# 4           574  2017-11-01 00:00:20  2017-11-01 00:09:54               458
#
#             start station name  start station latitude  \
# 0           Front St & Gold St               40.702240
# 1               24 St & 41 Ave               40.752709
# 2  Washington Ave & Greene Ave               40.686501
# 3          Broadway & W 122 St               40.812056
# 4             11 Ave & W 27 St               40.751396
#
#    start station longitude  end station id          end station name  \
# 0               -73.982578             414   Pearl St & Anchorage Pl
# ...

# %%
# use concat to append the rows of DF2 to DF1
concat_14 = pd.concat([concat_13, df_2017_11], sort=True)
# reset the index of the new DF
concat_14.reset_index()
concat_14.head()
# Out:
#    bikeid  birth year  end station id  end station latitude  \
# 0   25454      1966.0             430             40.701485
# 1   25930      1995.0            3158             40.771639
# 2   27110      1987.0             412             40.715816
# 3   28392      1961.0             411             40.722281
# 4   19316      1967.0            3300             40.665147
#
#    end station longitude           end station name  gender  start station id  \
# 0             -73.986569           York St & Jay St       1               217
# 1             -73.982614         W 63 St & Broadway       1               490
# 2             -73.994224      Forsyth St & Canal St       1               504
# 3             -73.976687          E 6 St & Avenue D       1               445
# 4             -73.976376  Prospect Park West & 8 St       2              3423
#
#    start station latitude  start station longitude  \
# 0               40.702772               -73.993836
# ...

# %%
# read files into dataframe for DF5
df_2017_12 = pd.read_csv(bike_2017_12)
df_2017_12.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           256  2017-12-01 00:00:00  2017-12-01 00:04:17               324
# 1           325  2017-12-01 00:00:17  2017-12-01 00:05:43               470
# 2           967  2017-12-01 00:00:19  2017-12-01 00:16:26               347
# 3           125  2017-12-01 00:00:20  2017-12-01 00:02:26              3077
# 4           451  2017-12-01 00:00:28  2017-12-01 00:08:00               368
#
#             start station name  start station latitude  \
# 0      DeKalb Ave & Hudson Ave               40.689888
# 1              W 20 St & 8 Ave               40.743453
# 2  Greenwich St & W Houston St               40.728846
# 3         Stagg St & Union Ave               40.708771
# 4           Carmine St & 6 Ave               40.730386
#
#    start station longitude  end station id        end station name  \
# 0               -73.981013             262         Washington Park
# ...

# %%
# use concat to append the rows of DF2 to DF1
concat_15 = pd.concat([concat_14, df_2017_12], sort=True)
# reset the index of the new DF
concat_15.reset_index()
concat_15.head()
# Out:
#    bikeid  birth year  end station id  end station latitude  \
# 0   25454      1966.0             430             40.701485
# 1   25930      1995.0            3158             40.771639
# 2   27110      1987.0             412             40.715816
# 3   28392      1961.0             411             40.722281
# 4   19316      1967.0            3300             40.665147
#
#    end station longitude           end station name  gender  start station id  \
# 0             -73.986569           York St & Jay St       1               217
# 1             -73.982614         W 63 St & Broadway       1               490
# 2             -73.994224      Forsyth St & Canal St       1               504
# 3             -73.976687          E 6 St & Avenue D       1               445
# 4             -73.976376  Prospect Park West & 8 St       2              3423
#
#    start station latitude  start station longitude  \
# 0               40.702772               -73.993836
# ...

# %%
# Rename the columns to be consistent with the expect
# I need to rename the column headings in the old dataframe to the new format.

concat_15 = concat_15.rename(columns={'tripduration':'Trip Duration', 'starttime':'Start Time', \
                         'stoptime':'Stop Time', 'start station id':'Start Station ID', \
                         'start station name':'Start Station Name', \
                         'start station latitude':'Start Station Latitude', \
                         'start station longitude':'Start Station Longitude', \
                         'end station id':'End Station ID', \
                         'end station name':'End Station Name', \
                         'end station latitude':'End Station Latitude', \
                         'end station longitude':'End Station Longitude', \
                         'bikeid':'Bike ID', \
                         'usertype':'User Type', \
                         'birth year':'Birth Year', \
                         'gender':'Gender'})
# check to see if columns are retitled
concat_15.head()
# Out:
#    Bike ID  Birth Year  End Station ID  End Station Latitude  \
# 0    25454      1966.0             430             40.701485
# 1    25930      1995.0            3158             40.771639
# 2    27110      1987.0             412             40.715816
# 3    28392      1961.0             411             40.722281
# 4    19316      1967.0            3300             40.665147
#
#    End Station Longitude           End Station Name  Gender  Start Station ID  \
# 0             -73.986569           York St & Jay St       1               217
# 1             -73.982614         W 63 St & Broadway       1               490
# 2             -73.994224      Forsyth St & Canal St       1               504
# 3             -73.976687          E 6 St & Avenue D       1               445
# 4             -73.976376  Prospect Park West & 8 St       2              3423
#
#    Start Station Latitude  Start Station Longitude  \
# 0               40.702772               -73.993836
# ...

# %%
# get # of rows for concatenate
concat_15_rows = concat_15.count()
print(concat_15_rows)
# Out:
# Bike ID                    14118669
# Birth Year                 12599579
# End Station ID             14118669
# End Station Latitude       14118669
# End Station Longitude      14118669
# End Station Name           14118669
# Gender                     14118669
# Start Station ID           14118669
# Start Station Latitude     14118669
# Start Station Longitude    14118669
# Start Station Name         14118669
# Start Time                 14118669
# Stop Time                  14118669
# Trip Duration              14118669
# User Type                  14118669
# dtype: int64

# %% [markdown]
# ### Steps to reduce file size

# %%
# Drop rows where any data is missing
concat_15 = concat_15.dropna(how='any')

# %%
# Reset index, Verify dropped rows
concat_15.reset_index()
concat_15.count()
# Out:
# Bike ID                    12599579
# Birth Year                 12599579
# End Station ID             12599579
# End Station Latitude       12599579
# End Station Longitude      12599579
# End Station Name           12599579
# Gender                     12599579
# Start Station ID           12599579
# Start Station Latitude     12599579
# Start Station Longitude    12599579
# Start Station Name         12599579
# Start Time                 12599579
# Stop Time                  12599579
# Trip Duration              12599579
# User Type                  12599579
# dtype: int64

# %%
# review data types to see if we can optimize the columns
concat_15.dtypes
# Out:
# Bike ID                      int64
# Birth Year                 float64
# End Station ID               int64
# End Station Latitude       float64
# End Station Longitude      float64
# End Station Name            object
# Gender                       int64
# Start Station ID             int64
# Start Station Latitude     float64
# Start Station Longitude    float64
# Start Station Name          object
# Start Time                  object
# Stop Time                   object
# Trip Duration                int64
# User Type                   object
# dtype: object

# %%
# see if I can change BIKE ID to smaller integer
concat_15['Bike ID'].min()
# Out:
# 14529

# %%
# see if I can change BIKE ID to smaller integer
concat_15['Bike ID'].max()
# Out:
# 33481

# %%
# change Bike ID from int64 to int32
concat_15['Bike ID'] = concat_15['Bike ID'].astype(np.int32)

# %%
# confirm change
concat_15.dtypes
# Out:
# Bike ID                      int32
# Birth Year                 float64
# End Station ID               int64
# End Station Latitude       float64
# End Station Longitude      float64
# End Station Name            object
# Gender                       int64
# Start Station ID             int64
# Start Station Latitude     float64
# Start Station Longitude    float64
# Start Station Name          object
# Start Time                  object
# Stop Time                   object
# Trip Duration                int64
# User Type                   object
# dtype: object

# %%
# see if I can change End Station ID to smaller integer
concat_15['End Station ID'].min()
# Out:
# 72

# %%
# see if I can change End Station ID to smaller integer
concat_15['End Station ID'].max()
# Out:
# 3654

# %%
# change End Station ID from int64 to int16
concat_15['End Station ID'] = concat_15['End Station ID'].astype(np.int16)

# %%
# confirm change
concat_15.dtypes
# Out:
# Bike ID                      int32
# Birth Year                 float64
# End Station ID               int16
# End Station Latitude       float64
# End Station Longitude      float64
# End Station Name            object
# Gender                       int64
# Start Station ID             int64
# Start Station Latitude     float64
# Start Station Longitude    float64
# Start Station Name          object
# Start Time                  object
# Stop Time                   object
# Trip Duration                int64
# User Type                   object
# dtype: object

# %%
# change Start Station ID from int64 to int16
concat_15['Start Station ID'] = concat_15['Start Station ID'].astype(np.int16)

# %%
# confirm change
concat_15.dtypes
# Out:
# Bike ID                      int32
# Birth Year                 float64
# End Station ID               int16
# End Station Latitude       float64
# End Station Longitude      float64
# End Station Name            object
# Gender                       int64
# Start Station ID             int16
# Start Station Latitude     float64
# Start Station Longitude    float64
# Start Station Name          object
# Start Time                  object
# Stop Time                   object
# Trip Duration                int64
# User Type                   object
# dtype: object

# %%
# see if I can change Gender to smaller integer
concat_15['Gender'].min()
# Out:
# 0

# %%
# see if I can change Gender to smaller integer
concat_15['Gender'].max()
# Out:
# 2

# %%
# change Gender from int64 to byte
concat_15['Gender'] = concat_15['Gender'].astype(np.byte)

# %%
# confirm change
concat_15.dtypes
# Out:
# Bike ID                      int32
# Birth Year                 float64
# End Station ID               int16
# End Station Latitude       float64
# End Station Longitude      float64
# End Station Name            object
# Gender                        int8
# Start Station ID             int16
# Start Station Latitude     float64
# Start Station Longitude    float64
# Start Station Name          object
# Start Time                  object
# Stop Time                   object
# Trip Duration                int64
# User Type                   object
# dtype: object

# %%
# see if I can change Trip Duration to smaller integer
concat_15['Trip Duration'].min()
# Out:
# 61

# %%
# see if I can change Trip Duration to smaller integer
concat_15['Trip Duration'].max()
# Out:
# 9735948

# %%
# remove all rows Trip Duration > 86,400 (24 hours)
# get names of indexes for Trip Duration column where TD > 86,400
indexNames3 = concat_15[concat_15['Trip Duration'] > 86400].index
concat_15.drop(indexNames3, inplace=True)

# %%
# check max Trip Duration
concat_15['Trip Duration'].max()
# Out:
# 86309

# %%
# Reset index, Verify dropped rows
concat_15.reset_index()
concat_15.count()
# Out:
# Bike ID                    12579602
# Birth Year                 12579602
# End Station ID             12579602
# End Station Latitude       12579602
# End Station Longitude      12579602
# End Station Name           12579602
# Gender                     12579602
# Start Station ID           12579602
# Start Station Latitude     12579602
# Start Station Longitude    12579602
# Start Station Name         12579602
# Start Time                 12579602
# Stop Time                  12579602
# Trip Duration              12579602
# User Type                  12579602
# dtype: int64

# %%
# confirm change
concat_15.dtypes
# Out:
# Bike ID                      int32
# Birth Year                 float64
# End Station ID               int16
# End Station Latitude       float64
# End Station Longitude      float64
# End Station Name            object
# Gender                        int8
# Start Station ID             int16
# Start Station Latitude     float64
# Start Station Longitude    float64
# Start Station Name          object
# Start Time                  object
# Stop Time                   object
# Trip Duration                int64
# User Type                   object
# dtype: object

# %%
# now change Trip Duration from int64 to int32
concat_15['Trip Duration'] = concat_15['Trip Duration'].astype(np.int32)

# %%
# confirm change
concat_15.dtypes
# Out:
# Bike ID                      int32
# Birth Year                 float64
# End Station ID               int16
# End Station Latitude       float64
# End Station Longitude      float64
# End Station Name            object
# Gender                        int8
# Start Station ID             int16
# Start Station Latitude     float64
# Start Station Longitude    float64
# Start Station Name          object
# Start Time                  object
# Stop Time                   object
# Trip Duration                int32
# User Type                   object
# dtype: object

# %%
# confirm change
concat_15.head()
# Out:
#    Bike ID  Birth Year  End Station ID  End Station Latitude  \
# 0    25454      1966.0             430             40.701485
# 1    25930      1995.0            3158             40.771639
# 2    27110      1987.0             412             40.715816
# 3    28392      1961.0             411             40.722281
# 4    19316      1967.0            3300             40.665147
#
#    End Station Longitude           End Station Name  Gender  Start Station ID  \
# 0             -73.986569           York St & Jay St       1               217
# 1             -73.982614         W 63 St & Broadway       1               490
# 2             -73.994224      Forsyth St & Canal St       1               504
# 3             -73.976687          E 6 St & Avenue D       1               445
# 4             -73.976376  Prospect Park West & 8 St       2              3423
#
#    Start Station Latitude  Start Station Longitude  \
# 0               40.702772               -73.993836
# ...

# %%
# export to csv
concat_15.to_csv("concat_15_201704_201712.csv", index=False, header=True)
